# %% [markdown]
# ## **Applied NLP with Hugging Face**

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)

# %% [markdown]
# ### **Sentiment Analysis**

# %%
from transformers import pipeline
classifier=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu

# %%
task=("This Nlp and Hugging Face course content is very good!")
classifier(task)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998644590377808}]

# %%
new_task=["This Nlp and Hugging Face course content is very good!", "But Balancing work and learning has been quite exhausting lately"]
classifier(new_task)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998644590377808},
#  {'label': 'NEGATIVE', 'score': 0.9994366765022278}]

# %%
classifier(
    ["This Nlp and Hugging Face course content is very good!", "But Balancing work and learning has been quite exhausting lately"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998644590377808},
#  {'label': 'NEGATIVE', 'score': 0.9994366765022278}]

# %%
results=classifier(new_task)
for result in results:
  print(f"Label: {result['label']}---> Score: {result['score']}")
# Out:
# Label: POSITIVE---> Score: 0.9998644590377808
# Label: NEGATIVE---> Score: 0.9994366765022278

# %% [markdown]
# ### **Zero-Shot Classification**

# %% [markdown]
# #### **Example No: 1**

# %%
from transformers import pipeline
zeroshot_classifier=pipeline("zero-shot-classification")
tasks=zeroshot_classifier(
    "This is the Nlp and Hugging Face Course",
    candidate_labels =["Education", "Teaching", "Politics","literacy"]
)
print(tasks)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# {'sequence': 'This is the Nlp and Hugging Face Course', 'labels': ['Teaching', 'literacy', 'Education', 'Politics'], 'scores': [0.30446070432662964, 0.27317050099372864, 0.2686637043952942, 0.1537051796913147]}

# %%
for label,score in zip(tasks['labels'], tasks['scores']):
  print(label,'-->',score)
# Out:
# Teaching --> 0.30446070432662964
# literacy --> 0.27317050099372864
# Education --> 0.2686637043952942
# Politics --> 0.1537051796913147

# %%
for task in tasks:
  print(f"Label: {tasks['labels']}---> Score: {tasks['scores']}")
# Out:
# Label: ['Teaching', 'literacy', 'Education', 'Politics']---> Score: [0.30446070432662964, 0.27317050099372864, 0.2686637043952942, 0.1537051796913147]
# Label: ['Teaching', 'literacy', 'Education', 'Politics']---> Score: [0.30446070432662964, 0.27317050099372864, 0.2686637043952942, 0.1537051796913147]
# Label: ['Teaching', 'literacy', 'Education', 'Politics']---> Score: [0.30446070432662964, 0.27317050099372864, 0.2686637043952942, 0.1537051796913147]

# %% [markdown]
# #### **Example No: 2**

# %%
zeroshot_tasks=zeroshot_classifier(
    "This is the Nlp course and it make my concepts very strong related to NLP",
    candidate_labels=["literacy", "Education", "Politics", "Teaching"]
)
for label, score in zip(zeroshot_tasks['labels'], zeroshot_tasks['scores']):
  print("Label:", label, '--->', "Score:", score)
  # print(f"Label: {zeroshot_tasks['labels']}---> Score: {zeroshot_tasks['scores']}")
# Out:
# Label: literacy ---> Score: 0.31649455428123474
# Label: Teaching ---> Score: 0.31614044308662415
# Label: Education ---> Score: 0.2477429360151291
# Label: Politics ---> Score: 0.11962203681468964

# %% [markdown]
# ### **Text Generation**

# %%
text_classifier=pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# <transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7a87bd902ad0>

# %%
from transformers import pipeline

text_generator = pipeline("text-generation")
output = text_generator("I'm learning NLP Course today and I have learned a lot from this course. Now I have to do", max_length=50)
print(output)
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "I'm learning NLP Course today and I have learned a lot from this course. Now I have to do it more. To help myself I think I am going to get a PhD, get another book for next year and do some more programming because"}]

# %% [markdown]
# #### **max_length parameter**

# %%
from transformers import pipeline

text_generator = pipeline("text-generation", max_length=25)
output = text_generator("I'm learning NLP Course today and I have learned a lot from this course. Now I have to do", max_length=50)
print(output)
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "I'm learning NLP Course today and I have learned a lot from this course. Now I have to do it because of time at work. I will be able to stay productive. In my new job, after 5 years, I'm still waiting"}]

# %% [markdown]
# #### **max_length parameter, max_new_tokens, num_return_sequences**

# %%
from transformers import pipeline

text_generator = pipeline("text-generation",  max_length=50,
                          max_new_tokens=50,
                          num_return_sequences=5,
                          "_from_model_config": true,
                          "bos_token_id": 50256,
                          "eos_token_id": 50256,)
output = text_generator("I'm learning NLP Course today and I have learned a lot from this course. Now I have to do", max_length=50)
print(output)
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "I'm learning NLP Course today and I have learned a lot from this course. Now I have to do another one and to get better at it. With the help of the teachers, everyone is getting to know the basic techniques and practice procedures that you might hear in other courses that are in the VLP. And to do that, you have to look"}, {'generated_text': 'I\'m learning NLP Course today and I have learned a lot from this course. Now I have to do a lot more on the part of the computer programs and I also have to do a lot more on how to code," Moore said.\n\nMoore told KOMO that he has now completed the four-hour courses and that there are now two'}, {'generated_text': "I'm learning NLP Course today and I have learned a lot from this course. Now I have to do it for the next exam. I will try and get it done before I go to the exam. In the meantime, I want to thank you for your willingness to learn my course.\n\nWhat do you think you learned in this course?\n"}, {'generated_text': 'I\'m learning NLP Course today and I have learned a lot from this course. Now I have to do whatever they call it… read about it. Then the next time I go, the next couple of times, go read about it!"\n\n"What is your NLP Course?" I asked once I got off of my bike, which is about'}, {'generated_text': 'I\'m learning NLP Course today and I have learned a lot from this course. Now I have to do better."\n\nThe second time this semester I have met him.\n\n"I\'ve studied it for a week," he said last week. "I\'ve had a lot of success with it, I\'ve had an important decision and I\'ve'}]

# %%
# !rm -rf /root/.cache/huggingface
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   38G   71G  35% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.2G  775M  61% /usr/sbin/docker-init
# tmpfs           6.4G   45M  6.3G   1% /var/colab
# /dev/sda1       114G  109G  5.2G  96% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
text_generator = pipeline("text-generation", model="distilgpt2")
output = text_generator("I'm learning NLP Course today and I have learned a lot from this course. Now I have to do", max_length=50)
print(output)
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "I'm learning NLP Course today and I have learned a lot from this course. Now I have to do something that will help.\n\nIt's actually more about starting a business on paper, not writing or teaching. You're going to need"}]

# %% [markdown]
# ### **Fill Mask**

# %%
from transformers import pipeline
fill_mask_classifier=pipeline("fill-mask")
mask_text="I'm studying NLP course and in this course i learned about <mask> models"
print(fill_mask_classifier(mask_text))
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.1395835280418396, 'token': 30412, 'token_str': ' mathematical', 'sequence': "I'm studying NLP course and in this course i learned about mathematical models"}, {'score': 0.08340431749820709, 'token': 17325, 'token_str': ' statistical', 'sequence': "I'm studying NLP course and in this course i learned about statistical models"}, {'score': 0.038232721388339996, 'token': 27930, 'token_str': ' predictive', 'sequence': "I'm studying NLP course and in this course i learned about predictive models"}, {'score': 0.03449699655175209, 'token': 38163, 'token_str': ' computational', 'sequence': "I'm studying NLP course and in this course i learned about computational models"}, {'score': 0.033500395715236664, 'token': 26956, 'token_str': ' linear', 'sequence': "I'm studying NLP course and in this course i learned about linear models"}]

# %%
from transformers import pipeline
fill_mask_classifier=pipeline("fill-mask")
mask_text="I'm studying NLP course and this <mask> is very informative"
print(fill_mask_classifier(mask_text))
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.1299324929714203, 'token': 1566, 'token_str': ' article', 'sequence': "I'm studying NLP course and this article is very informative"}, {'score': 0.08656145632266998, 'token': 17299, 'token_str': ' lecture', 'sequence': "I'm studying NLP course and this lecture is very informative"}, {'score': 0.08081753551959991, 'token': 1040, 'token_str': ' book', 'sequence': "I'm studying NLP course and this book is very informative"}, {'score': 0.05464499071240425, 'token': 2225, 'token_str': ' paper', 'sequence': "I'm studying NLP course and this paper is very informative"}, {'score': 0.04773835837841034, 'token': 618, 'token_str': ' post', 'sequence': "I'm studying NLP course and this post is very informative"}]

# %% [markdown]
# ### **Named Entity Recognition (NER)**

# %%
ner_classifier=pipeline("ner", model="dslim/bert-base-NER")
ner_text="I'm doing Datascience and Ai and I have just completed by Bachelors and now i'm creating various projects on GitHub and kaggle"
print(ner_classifier(ner_text))
# Out:
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu
# [{'entity': 'B-ORG', 'score': np.float32(0.9871841), 'index': 5, 'word': 'Data', 'start': 10, 'end': 14}, {'entity': 'I-ORG', 'score': np.float32(0.9916128), 'index': 6, 'word': '##science', 'start': 14, 'end': 21}, {'entity': 'B-ORG', 'score': np.float32(0.84899354), 'index': 8, 'word': 'Ai', 'start': 26, 'end': 28}, {'entity': 'B-ORG', 'score': np.float32(0.7211428), 'index': 26, 'word': 'G', 'start': 109, 'end': 110}, {'entity': 'I-ORG', 'score': np.float32(0.7434235), 'index': 27, 'word': '##it', 'start': 110, 'end': 112}, {'entity': 'I-ORG', 'score': np.float32(0.74996173), 'index': 28, 'word': '##H', 'start': 112, 'end': 113}, {'entity': 'I-ORG', 'score': np.float32(0.6072182), 'index': 29, 'word': '##ub', 'start': 113, 'end': 115}]

# %%
ner_classifier=pipeline("ner", model="dslim/bert-base-NER", grouped_entities=True)
ner_text="I'm doing Datascience and Ai and I have just completed by Bachelors and now i'm creating various projects on GitHub and kaggle"
print(ner_classifier(ner_text))
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/token_classification.py:170: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   warnings.warn(
# [{'entity_group': 'ORG', 'score': np.float32(0.9893985), 'word': 'Datascience', 'start': 10, 'end': 21}, {'entity_group': 'ORG', 'score': np.float32(0.84899354), 'word': 'Ai', 'start': 26, 'end': 28}, {'entity_group': 'ORG', 'score': np.float32(0.7054366), 'word': 'GitHub', 'start': 109, 'end': 115}]

# %% [markdown]
# ### **Question Answering**

# %%
from transformers import pipeline
qa_classifier = pipeline("question-answering", model="PlanTL-GOB-ES/roberta-base-bne-sqac")
qa= qa_classifier(
    context="I'm doing Datascience and Ai and I have just completed by Bachelors and now i'm creating various projects on GitHub and kaggle",
    question="What I'm doing nowadays"
)
print(qa)
# Out:
# Device set to use cpu
# {'score': 0.000540809822268784, 'start': 10, 'end': 21, 'answer': 'Datascience'}

# %%
from transformers import pipeline
qa_classifier = pipeline("question-answering", model="PlanTL-GOB-ES/roberta-base-bne-sqac")
qa= qa_classifier(
    context="I'm doing Datascience and Ai and I have just completed by Bachelors and now i'm creating various projects on GitHub and kaggle",
    question="What I've studied?"
)
print(qa)
# Out:
# Device set to use cpu
# {'score': 3.546431253198534e-05, 'start': 58, 'end': 67, 'answer': 'Bachelors'}

# %% [markdown]
# ### **Text Summerization**

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
new_text="""Artificial Intelligence (AI) has rapidly evolved over the past few decades, transforming from a concept of science fiction into a powerful tool reshaping industries and societies. In the early days, AI was limited to performing specific tasks in controlled environments, such as playing chess or solving mathematical problems. However, with the advent of machine learning and deep learning, AI systems have become increasingly capable of handling complex, real-world problems with remarkable accuracy and speed.

Today, AI technologies are being applied in a wide range of fields including healthcare, finance, transportation, education, and entertainment. In healthcare, AI algorithms can diagnose diseases from medical images, suggest treatment plans, and even predict patient outcomes. In finance, AI is used for fraud detection, algorithmic trading, and personalized financial advice. Autonomous vehicles rely heavily on AI for navigating roads, avoiding obstacles, and making split-second decisions. In education, AI-powered tutoring systems can adapt to the learning styles of individual students, helping them master difficult subjects more effectively.

Despite these advancements, AI also raises important ethical and societal questions. Issues such as data privacy, algorithmic bias, job displacement, and the potential misuse of AI technologies are topics of growing concern. Governments, researchers, and organizations around the world are working together to establish frameworks and regulations that ensure AI is developed and used responsibly.

As we look to the future, the role of AI will likely become even more significant. Emerging trends like explainable AI, federated learning, and AI in climate modeling are expected to play a critical role in addressing global challenges. By continuing to invest in research, fostering collaboration across disciplines, and prioritizing ethical considerations, we can harness the full potential of AI to create a better and more equitable world."""
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
print(summarizer(new_text))
# Out:
# [{'summary_text': 'Artificial Intelligence (AI) has rapidly evolved over the past few decades. In healthcare, AI algorithms can diagnose diseases from medical images. In finance, AI is used for fraud detection, algorithmic trading, and personalized financial advice. Autonomous vehicles rely heavily on AI for navigating roads, avoiding obstacles, and making split-second decisions.'}]

# %%
summarizer = pipeline("summarization", model="google/pegasus-xsum")
new_text="""Artificial Intelligence (AI) has rapidly evolved over the past few decades, transforming from a concept of science fiction into a powerful tool reshaping industries and societies. In the early days, AI was limited to performing specific tasks in controlled environments, such as playing chess or solving mathematical problems. However, with the advent of machine learning and deep learning, AI systems have become increasingly capable of handling complex, real-world problems with remarkable accuracy and speed.

Today, AI technologies are being applied in a wide range of fields including healthcare, finance, transportation, education, and entertainment. In healthcare, AI algorithms can diagnose diseases from medical images, suggest treatment plans, and even predict patient outcomes. In finance, AI is used for fraud detection, algorithmic trading, and personalized financial advice. Autonomous vehicles rely heavily on AI for navigating roads, avoiding obstacles, and making split-second decisions. In education, AI-powered tutoring systems can adapt to the learning styles of individual students, helping them master difficult subjects more effectively.

Despite these advancements, AI also raises important ethical and societal questions. Issues such as data privacy, algorithmic bias, job displacement, and the potential misuse of AI technologies are topics of growing concern. Governments, researchers, and organizations around the world are working together to establish frameworks and regulations that ensure AI is developed and used responsibly.

As we look to the future, the role of AI will likely become even more significant. Emerging trends like explainable AI, federated learning, and AI in climate modeling are expected to play a critical role in addressing global challenges. By continuing to invest in research, fostering collaboration across disciplines, and prioritizing ethical considerations, we can harness the full potential of AI to create a better and more equitable world."""
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/259 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Device set to use cpu

# %%
print(summarizer(new_text))
# Out:
# [{'summary_text': 'Artificial Intelligence (AI) has rapidly evolved over the past few decades, transforming from a concept of science fiction into a powerful tool reshaping industries and societies.'}]

# %% [markdown]
# ### **Translation**

# %%
from transformers import pipeline
translator=pipeline("translation", model="Helsinki-NLP/opus-mt-en-ur")
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/306M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/816k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/848k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu

# %%
ai_text="""Artificial Intelligence (AI) has rapidly evolved over the past few decades

Today, AI technologies are being applied in a wide range of fields including healthcare, finance, transportation, education, and entertainment. In healthcare, AI algorithms can diagnose diseases from medical images, suggest treatment plans, and even predict patient outcomes. In finance, AI is used for fraud detection, algorithmic trading, and personalized financial advice. Autonomous vehicles rely heavily on AI for navigating roads, avoiding obstacles, and making split-second decisions. In education, AI-powered tutoring systems can adapt to the learning styles of individual students, helping them master difficult subjects more effectively.
"""
print(translator(ai_text))
# Out:
# [{'translation_text': 'ٹیکنالوجی کی تیزی سے تیزی سے بڑھ رہی ہے، جو کہ ماضی میں تیزی سے ترقی کر رہا ہے صحت، تعلیم، سرمایہ کار، تعلیمی مسائل اور کھیلوں میں استعمال کیا جا رہا ہے۔'}]
